# %% [markdown]
# # Step 1: HI Construction
# 1. Normalization & feature selection
# 2. Noise reduction (Gaussian filter)
# 3. Dimension reduction (PCA)

# %% [markdown]
# ## 1 Import library

# %%
import pandas as pd
import numpy as np
import os
import time
import csv
import math
import matplotlib.pyplot as plt
from sklearn import preprocessing
from scipy.ndimage.filters import gaussian_filter1d
from sklearn.decomposition import PCA

# %% [markdown]
# ## 2 Load data

# %% [markdown]
# ### 2.1 Set constant data

# %%
file_path = '0_raw_data/'
file_no = '1'
train_file = file_path+'train_FD00'+file_no+'.txt'
test_file = file_path+'test_FD00'+file_no+'.txt'
test_rul_file = file_path+'RUL_FD00'+file_no+'.txt'
n_ftrs = 26
op_col_name = [ 'setting1', 'setting2', 'setting3']
ftr_col_name = [ 's1', 's2', 's3','s4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
             's15', 's16', 's17', 's18', 's19', 's20', 's21']
col_name = ['id', 'cycle'] + op_col_name+ ftr_col_name
n_op = 1

# %% [markdown]
# ### 2.2 Read data

# %%
# read training data - It is the aircraft engine run-to-failure data.
raw_train_df = pd.read_csv(train_file,names = col_name, header=None,delim_whitespace=True,index_col=0)
raw_test_df = pd.read_csv(test_file,names = col_name, header=None,delim_whitespace=True,index_col=0)
raw_rul_df = pd.read_csv(test_rul_file, names=['RUL'],header=None,delim_whitespace=True)

# %%
train_df = raw_train_df
test_df = raw_test_df
rul_df = raw_rul_df

# %%
n_train_units = len(train_df.groupby('id').size())
n_test_units = len(test_df.groupby('id').size())
n_test_units
# Out:
# 100

# %% [markdown]
# ## 3 Preprocess

# %% [markdown]
# ### 3.1 Normalization

# %%
scaler = preprocessing.StandardScaler()
train_df[ftr_col_name] = pd.DataFrame(scaler.fit_transform(train_df[ftr_col_name]), 
                                                        columns=ftr_col_name, 
                                                        index=train_df.index)

# %%
test_df[ftr_col_name] = pd.DataFrame(scaler.transform(test_df[ftr_col_name]), 
                                                        columns=ftr_col_name, 
                                                        index=test_df.index)

# %% [markdown]
# ### 3.2 Calculate RUL

# %%
train_df['RUL'] = ''
for i in range(n_train_units):
    train_df.loc[i + 1,'RUL'] = train_df.loc[i + 1,'cycle'].max() - train_df.loc[i + 1,'cycle']

# %%
test_df['RUL'] = ''
for i in range(n_test_units):
    test_df.loc[i + 1,'RUL'] =  - test_df.loc[i + 1,'cycle'] + (test_df.loc[i + 1,'cycle'].max() + rul_df.loc[i,'RUL'])

# %% [markdown]
# ### 3.3 Piecewise RUL

# %% [raw]
# MAX_RUL=130
# train_df.loc[train_df['RUL']>MAX_RUL,'RUL']=MAX_RUL
# test_df.loc[test_df['RUL']>MAX_RUL,'RUL']=MAX_RUL

# %% [markdown]
# ### 3.4 Drop rebundant features

# %%
#rebundant_ftr_name = ['s1','s5','s6','s10','s16','s17','s18','s19','setting1','setting2','setting3']
rebundant_ftr_name = ['s1','s5','s6', 's8', 's9','s10', 's13', 's14','s16','s17','s18','s19', 's20', 's21','setting1','setting2','setting3']

# %%
#train_df =train_df.loc[:,selected_ftr_name]
train_df.drop(rebundant_ftr_name, axis=1, inplace=True)
#train_df.head()

# %%
test_df.drop(rebundant_ftr_name, axis=1, inplace=True)

# %%
selected_ftr_name = train_df.columns.difference(['id','cycle','RUL'])
selected_ftr_name
# Out:
# Index(['s11', 's12', 's15', 's2', 's3', 's4', 's7'], dtype='object')

# %% [markdown]
# ## 4 Noise reduction

# %% [markdown]
# ### 4.1 Gaussian filter

# %%
def smoothGaussian(data,ftr_col_name,sigma):
    for unit_no in data.index.unique():
        for col in ftr_col_name:
            data.loc[unit_no, col] = gaussian_filter1d(data.loc[unit_no,col], sigma)
    return data

# %%
gauss_sigma = 3
train_df = smoothGaussian(train_df, selected_ftr_name,gauss_sigma)

# %%
test_df = smoothGaussian(test_df, selected_ftr_name,gauss_sigma)

# %%
unit_no = 2
plt.plot(range(len(train_df.loc[unit_no])),train_df.loc[unit_no,'s2'])
plt.plot(range(len(test_df.loc[unit_no])),test_df.loc[unit_no,'s4'])
plt.show()

# %% [markdown]
# ## 5 Dimension reduction

# %% [markdown]
# ### 5.1 PCA

# %%
pca = PCA(n_components=3)
pca.fit(train_df[selected_ftr_name])
train_pca = pca.transform(train_df[selected_ftr_name])
test_pca = pca.transform(test_df[selected_ftr_name])
sum(pca.explained_variance_ratio_[:3])
# Out:
# 0.9907892499512343

# %%
pca.explained_variance_ratio_[:3]
# Out:
# array([0.97944869, 0.00763819, 0.00370237])

# %%
train_df['HI'] = pd.DataFrame(train_pca[:,0],index = train_df.index)
test_df['HI'] = pd.DataFrame(test_pca[:,0],index = test_df.index)

# %%
train_df
# Out:
#      cycle        s2        s3        s4        s7       s11       s12  \
# id
# 1        1 -0.934031 -0.518202 -0.815417  0.909791 -0.889393  1.011533
# 1        2 -0.928596 -0.523217 -0.821319  0.906845 -0.898700  1.004192
# 1        3 -0.918112 -0.532695 -0.832544  0.901018 -0.916229  0.989628
# 1        4 -0.903251 -0.545631 -0.848009  0.892464 -0.939992  0.968152
# 1        5 -0.884803 -0.560742 -0.866250  0.881470 -0.967400  0.940388
# 1        6 -0.863497 -0.576652 -0.885608  0.868484 -0.995666  0.907390
# 1        7 -0.839881 -0.592049 -0.904443  0.854126 -1.022191  0.870690
# 1        8 -0.814289 -0.605786 -0.921350  0.839155 -1.044897  0.832260
# 1        9 -0.786897 -0.616904 -0.935345  0.824403 -1.062441  0.794372
# 1       10 -0.757849 -0.624618 -0.945981  0.810677 -1.074271  0.759370
# 1       11 -0.727397 -0.628277 -0.953387  0.798667 -1.080555  0.729428
# 1       12 -0.696012 -0.627345 -0.958202  0.788863 -1.081982  0.706325
# 1       13 -0.664426 -0.621406 -0.961438  0.781505 -1.079502  0.691280
# 1       14 -0.633618 -0.610198 -0.964284  0.776586 -1.074057  0.684893
# 1       15 -0.604736 -0.593677 -0.967894  0.773903 -1.066360  0.687160
# 1       16 -0.579000 -0.572089 -0.973199  0.773150 -1.056777  0.697557
# 100    195  1.594689  1.686975  2.092002 -2.331635  2.219509 -2.190051
# 100    196  1.602150  1.719047  2.135200 -2.381203  2.252663 -2.228531
# 100    197  1.609173  1.746232  2.171110 -2.426317  2.280081 -2.260620
# 100    198  1.615177  1.767636  2.198823 -2.463874  2.301281 -2.285563
# 100    199  1.619576  1.782442  2.217665 -2.490900  2.315766 -2.302658
# 100    200  1.621906  1.790018  2.227193 -2.505056  2.323126 -2.311355
#
#           s15  RUL        HI
# id
# 1   -0.829887  191 -2.246080
# 1   -0.833643  190 -2.249248
# 1   -0.840494  189 -2.254698
# 1   -0.849236  188 -2.260837
# 1   -0.858336  187 -2.265682
# 1   -0.866183  186 -2.267246
# 1   -0.871346  185 -2.263912
# 1   -0.872777  184 -2.254714
# 1   -0.869942  183 -2.239495
# 1   -0.862861  182 -2.218907
# 1   -0.852082  181 -2.194280
# 1   -0.838585  180 -2.167396
# 1   -0.823653  179 -2.140215
# 1   -0.808714  178 -2.114608
# 1   -0.795169  177 -2.092147
# 1   -0.784229  176 -2.073973
# 1   -0.776750  175 -2.060770
# 1   -0.773126  174 -2.052801
# 1   -0.773223  173 -2.050013
# 1   -0.776408  172 -2.052143
# 1   -0.781649  171 -2.058806
# 1   -0.787683  170 -2.069535
# 1   -0.793221  169 -2.083787
# 1   -0.797144  168 -2.100920
# 1   -0.798644  167 -2.120188
# 1   -0.797311  166 -2.140764
# 1   -0.793133  165 -2.161811
# 1   -0.786444  164 -2.182584
# 1   -0.777843  163 -2.202511
# 1   -0.768106  162 -2.221242
# ..        ...  ...       ...
# 100  1.216654   29  3.149361
# 100  1.265950   28  3.212400
# 100  1.310031   27  3.270765
# 100  1.349826   26  3.326175
# 100  1.386124   25  3.380556
# 100  1.419304   24  3.435793
# 100  1.449226   23  3.493561
# 100  1.475335   22  3.555233
# 100  1.496932   21  3.621874
# 100  1.513563   20  3.694299
# 100  1.525380   19  3.773135
# 100  1.533394   18  3.858861
# 100  1.539511   17  3.951804
# 100  1.546349   16  4.052079
# 100  1.556859   15  4.159520
# 100  1.573843   14  4.273618
# 100  1.599477   13  4.393506
# 100  1.634941   12  4.517996
# 100  1.680222   11  4.645655
# 100  1.734129   10  4.774883
# 100  1.794479    9  4.903966
# 100  1.858431    8  5.031072
# 100  1.922865    7  5.154205
# 100  1.984751    6  5.271127
# 100  2.041439    5  5.379310
# 100  2.090841    4  5.475954
# 100  2.131481    3  5.558099
# 100  2.162443    2  5.622844
# 100  2.183244    1  5.667629
# 100  2.193677    0  5.690537
#
# [20631 rows x 10 columns]

# %%
for j in [2,9]:#range(1,10):
    plt.plot(range(len(train_df.loc[j])),train_df.loc[j,"HI"])
plt.show()

# %% [markdown]
# ### 6 Save HI

# %%
processed_data_file = '1_processed_data'
if os.path.exists(processed_data_file)==False:
    os.makedirs(processed_data_file)

# %%
train_df.to_csv(processed_data_file+'/train_PCA_data.csv',index=True,header=True)

# %%
test_df.to_csv(processed_data_file+'/test_PCA_data.csv',index=True,header=True)
